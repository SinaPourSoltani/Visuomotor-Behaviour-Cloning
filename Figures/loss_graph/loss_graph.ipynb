# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
with open(file) as json_file: 
    summary = json.load(json_file)
    train_loss = summary["Train losses"]
    val_loss = summary["Test loss"]
    
    fig = plt.figure(1)
    plt.plot(train_loss[:15])
    plt.plot(val_loss[:15])    
    plt.plot(train_loss[:5] + train_loss[15:25])
    plt.plot(val_loss[:5] + val_loss[15:25])



plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legends(["Baseline Train", "Baseline Valid", "Unfrozen Train", "Unfrozen Valid"])
# Out:
# Text(0, 0.5, 'Accuracy')
